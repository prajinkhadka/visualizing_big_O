# %%
from math import log
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.style.use('bmh')
n= np.linspace(1,10,1000)
labels = ['Constant', 'LogArithmentic', 'Linear', 'log Linear', 'Quadratic', 'cubic', 'exponential']
big_o = [np.ones(n.shape), np.log(n), n, n*np.log(n), n**2 , n**3, 2**n]

plt.figure(figsize = (12,10))
plt.ylim(0, 50)

for i in range(len(big_o)):
    plt.plot(n, big_o[i], label = labels[i])
    
plt.legend(loc =0)
plt.ylabel("runtime with data")
plt.xlabel('n')
# Out:
# Text(0.5,0,'n')
